# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\aishushah\anaconda3\lib\site-packages (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\aishushah\anaconda3\lib\site-packages (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\aishushah\anaconda3\lib\site-packages (3.4.3)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\aishushah\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six in c:\users\aishushah\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
G = nx.Graph()

G.add_edges_from([[1,2], [2,3], [1,3], [1,4], [1,5], [3,5],
                  [6,7], [7,8], [8,9], [6,9], [6,8], [7,9],
                  [10,11], [11,12], [10,12],
                  [9,12], [2,7]])

nx.draw(G, with_labels=True, node_color='g')

# %% [markdown]
# # Pair of Nodes In The Network

# %%
TOT_PAIRS = (12*11)/2
TOT_PAIRS
# Out:
# 66.0

# %% [markdown]
# # Highest / Lowest

# %%
# 2-  7
35 / TOT_PAIRS

# 12 - 9
# 27/TOT_PAIRS
# Out:
# 0.5303030303030303

# %%
nx.edge_betweenness_centrality(G)
# Out:
# {(1, 2): 0.30303030303030304,
#  (1, 3): 0.030303030303030304,
#  (1, 4): 0.16666666666666669,
#  (1, 5): 0.09090909090909091,
#  (2, 3): 0.18181818181818182,
#  (2, 7): 0.5303030303030303,
#  (3, 5): 0.07575757575757576,
#  (6, 7): 0.09090909090909091,
#  (6, 9): 0.06060606060606061,
#  (6, 8): 0.015151515151515152,
#  (7, 8): 0.09090909090909091,
#  (7, 9): 0.36363636363636365,
#  (8, 9): 0.06060606060606061,
#  (9, 12): 0.4090909090909091,
#  (10, 11): 0.015151515151515152,
#  (10, 12): 0.15151515151515152,
#  (11, 12): 0.15151515151515152}

# %%
edge_betwenness = nx.edge_betweenness_centrality(G).items()
sorted(edge_betwenness, key=lambda pair: -pair[1])[0][0]
# Out:
# (2, 7)

# %%
NUM_ITERATIONS = 5

for i in range(NUM_ITERATIONS):
    edge_betweenness = nx.edge_betweenness_centrality(G).items()
    edge_to_delete = sorted(edge_betweenness, key=lambda pair: -pair[1])[0][0]
    
    G.remove_edge(*edge_to_delete)
    
    nx.draw(G, with_labels=True, node_color='g')
    
    plt.title('Step %s\nEdge %s Deleted'%(i, edge_to_delete), fontsize=20)
    
    plt.show()
